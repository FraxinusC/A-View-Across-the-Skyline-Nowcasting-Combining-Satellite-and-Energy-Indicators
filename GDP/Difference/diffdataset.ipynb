# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import pandas as pd
import datetime
import random
import os
import rasterio
from tqdm import tqdm
import pickle
from rasterio.enums import Resampling

# %%
# 数据预处理函数
def preprocess_data(file_path):
    df = pd.read_csv(file_path)

    # Applying the specified transformations
    df['Time'] = df['Year'].apply(lambda x: datetime.datetime(x, 1, 1))

    # Log transformation
    cols_to_log_transform = ['GDP', 'Population', 'Personalincome', 'Percapitapersonalincome', 'econs', 'aland', 'awater','shape_area','shape_leng','Natural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet']
    df[cols_to_log_transform] = df[cols_to_log_transform].apply(np.log)

    # Sorting and handling previous year's GDP and Image Path
    df.sort_values(by=['GeoFIPS', 'Time'], inplace=True)
    df['previous_image_path'] = df.groupby('GeoFIPS')['ImagePath'].shift(1)
    df['PreviousYearGDP'] = df.groupby('GeoFIPS')['GDP'].shift(1)
    df['PreviousYearPopulation'] = df.groupby('GeoFIPS')['Population'].shift(1)
    df['PreviousYearPersonalincome'] = df.groupby('GeoFIPS')['Personalincome'].shift(1)
    df['PreviousYearPercapitapersonalincome'] = df.groupby('GeoFIPS')['Percapitapersonalincome'].shift(1)
    df['PreviousYearecons'] = df.groupby('GeoFIPS')['econs'].shift(1)
    df['PreviousYearNatural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet'] = df.groupby('GeoFIPS')['Natural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet'].shift(1)
    
    # Renaming ImagePath to current_image_path
    df.rename(columns={'ImagePath': 'current_image_path'}, inplace=True)

    # Adding a column to check for continuous records
    df['IsContinuous'] = (df['Year'] - df.groupby('GeoFIPS')['Year'].shift(1)) == 1

    # Filtering out non-continuous records
    df_filtered = df[df['IsContinuous'] & df['previous_image_path'].notna()].copy()

    # Calculating GDP Difference
    df_filtered['GDPDifference'] = df_filtered['GDP'] - df_filtered['PreviousYearGDP']
    df_filtered['PopulationDifference'] = df_filtered['Population'] - df_filtered['PreviousYearPopulation']
    df_filtered['PersonalincomeDifference'] = df_filtered['Personalincome'] - df_filtered['PreviousYearPersonalincome']
    df_filtered['econsDifference'] = df_filtered['econs'] - df_filtered['PreviousYearecons']
    df_filtered['Natural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet Difference'] = df_filtered['Natural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet'] - df_filtered['PreviousYearNatural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet']
    
    # Dropping unnecessary columns
    df_cleaned = df_filtered.drop(['IsContinuous'], axis=1)
    
    df_cleaned.head()
    return df_cleaned

# %%
class EconomicDataset(Dataset):
    def __init__(self, dataframe, root_dir, economic_features, img_size, img_augmented_size, scale_factor=0.8, transform=None, scaler=None):
        self.dataframe = dataframe
        self.root_dir = root_dir
        self.img_size = img_size
        self.img_augmented_size = img_augmented_size
        self.transform = transform
        self.economic_features = economic_features
        self.scale_factor = scale_factor
        self.scaler = scaler


    def read_and_resize_image(self, image_path):
        with rasterio.open(image_path) as src:
            # 调整读取分辨率
            data = src.read(
                out_shape=(
                    src.count,
                    int(src.height * self.scale_factor),
                    int(src.width * self.scale_factor)
                ),
                resampling=Resampling.bilinear
            )
            data = data.astype('float32')  # 转换数据类型
            nan_mask = np.isnan(data)
            data[nan_mask] = 0  # 替换 NaN 值
            return data

    def random_transform(self, image):
        # 随机水平翻转
        if random.random() > 0.5:
            image = np.flip(image, axis=2)  # 使用 NumPy 的切片操作进行翻转

        # 中心裁剪
        _, height, width = image.shape
        new_height = new_width = min(height, width)
        top = (height - new_height) // 2
        left = (width - new_width) // 2
        image = image[:, top:top + new_height, left:left + new_width].copy()

        # 在转换之前复制 NumPy 数组
        image = torch.from_numpy(image).float()

        # 调整图像大小
        image = F.interpolate(image.unsqueeze(0), size=(self.img_size, self.img_size), mode='bilinear', align_corners=False).squeeze(0)

        # 将图像像素值裁剪到范围 [0, 1]
        image = torch.clamp(image, 0, 1)

        return image

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        current_img_path = os.path.join(self.root_dir, self.dataframe.iloc[idx]['current_image_path'])
        previous_img_path = os.path.join(self.root_dir, self.dataframe.iloc[idx]['previous_image_path'])

        # 图像读取与变换
        current_image = self.read_and_resize_image(current_img_path)
        previous_image = self.read_and_resize_image(previous_img_path)
        current_image = self.random_transform(current_image)
        previous_image = self.random_transform(previous_image)

        # 当前和前一年的经济特征（注意 idx 在三个 tensor 中是一致的）
        current_econ_features = self.economic_features[idx].float()

        # 找到对应行中前一年的经济特征列并标准化（根据 scaler）
        prev_row = self.dataframe.iloc[idx]
        prev_econ_values = [
            prev_row['PreviousYearecons'],
            prev_row['PreviousYearPopulation'],
            prev_row['PreviousYearPersonalincome'],
            prev_row['PreviousYearPercapitapersonalincome'],
            prev_row['aland'],
            prev_row['awater'],
            prev_row['shape_area'],
            prev_row['shape_leng'],
            prev_row['PreviousYearNatural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet'],
            prev_row['intptlat'],
            prev_row['intptlon']
        ]
        prev_econ_values = np.array(prev_econ_values).astype(np.float32).reshape(1, -1)
        prev_econ_scaled = torch.tensor(self.scaler.transform(prev_econ_values), dtype=torch.float32).squeeze(0)
        columns_to_scale = ['econs','Population', 'Personalincome', 'Percapitapersonalincome', 'aland', 'awater',
                    'shape_area','shape_leng','Natural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet',
                    'intptlat','intptlon']

        prev_econ_df = pd.DataFrame(prev_econ_values, columns=columns_to_scale)
        prev_econ_scaled = torch.tensor(self.scaler.transform(prev_econ_df), dtype=torch.float32).squeeze(0)

        econ_diff = current_econ_features - prev_econ_scaled

        # 标签
        GDPDifference = self.dataframe.iloc[idx]['GDPDifference']

        return current_image, previous_image, current_econ_features, prev_econ_scaled, econ_diff, GDPDifference

# %%
from sklearn.preprocessing import StandardScaler
# 修改后的数据集划分函数
def create_datasets(df_cleaned, img_size, img_augmented_size):
    # 按 GeoFIPS 分组，然后分别划分每组数据
    grouped = df_cleaned.groupby('GeoFIPS')
    train_df_list = []
    val_df_list = []
    test_df_list = []

    for _, group in grouped:
        train, temp = train_test_split(group, test_size=0.3, random_state=42)
        val, test = train_test_split(temp, test_size=0.5, random_state=42)
        train_df_list.append(train)
        val_df_list.append(val)
        test_df_list.append(test)

    train_df = pd.concat(train_df_list)
    val_df = pd.concat(val_df_list)
    test_df = pd.concat(test_df_list)
    # 缩放经济特征
    scaler = MinMaxScaler()
    columns_to_scale = ['econs','Population', 'Personalincome', 'Percapitapersonalincome', 'aland', 'awater','shape_area','shape_leng','Natural Gas Delivered to Consumers in California (Including Vehicle Fuel)  Million Cubic Feet','intptlat','intptlon']
    scaler.fit(train_df[columns_to_scale])
    
    train_features = scaler.transform(train_df[columns_to_scale])
    test_features = scaler.transform(test_df[columns_to_scale])
    val_features = scaler.transform(val_df[columns_to_scale])
    train_features_tensor = torch.tensor(train_features, dtype=torch.float32)
    test_features_tensor = torch.tensor(test_features, dtype=torch.float32)
    val_features_tensor = torch.tensor(val_features, dtype=torch.float32)
    # 实例化数据集
    train_dataset = EconomicDataset(train_df, "<train_image_path>", train_features_tensor, img_size, img_augmented_size, scaler=scaler)
    val_dataset = EconomicDataset(val_df, "<validation_image_path>", val_features_tensor, img_size, img_augmented_size, scaler=scaler)
    test_dataset = EconomicDataset(test_df, "<test_image_path>", test_features_tensor, img_size, img_augmented_size, scaler=scaler)


    return train_dataset, val_dataset, test_dataset

# %%
def process_and_save_dataset(dataset, save_path):
    processed_data = []
    for i in tqdm(range(len(dataset))):
        cur_img, prev_img, cur_econ, prev_econ, econ_diff, label = dataset[i]

        # 替换 NaN
        cur_econ[torch.isnan(cur_econ)] = 0
        prev_econ[torch.isnan(prev_econ)] = 0
        econ_diff[torch.isnan(econ_diff)] = 0

        processed_data.append((cur_img, prev_img, cur_econ, prev_econ, econ_diff, label))

    with open(save_path, 'wb') as f:
        pickle.dump(processed_data, f)

    print(f"Saved processed data to {save_path}")

# %%
df_cleaned = preprocess_data("E://FYP//fypcode//Data//Label//ccc.csv")

# %%
# 创建数据集
train_dataset, val_dataset, test_dataset = create_datasets(df_cleaned, 512, 512)

# 处理和保存数据集到新的文件夹
process_and_save_dataset(train_dataset, "5f_train_dataset.pkl")
process_and_save_dataset(val_dataset, "5f_val_dataset.pkl")
process_and_save_dataset(test_dataset, "5f_test_dataset.pkl")
# Out:
#   0%|          | 0/709 [00:00<?, ?it/s]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   0%|          | 1/709 [00:02<26:42,  2.26s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   0%|          | 2/709 [00:04<26:49,  2.28s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   0%|          | 3/709 [00:06<27:06,  2.30s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|          | 4/709 [00:09<26:23,  2.25s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|          | 5/709 [00:11<25:18,  2.16s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|          | 6/709 [00:13<24:59,  2.13s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|          | 7/709 [00:15<25:44,  2.20s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|          | 8/709 [00:17<25:58,  2.22s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|▏         | 9/709 [00:19<25:20,  2.17s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   1%|▏         | 10/709 [00:21<24:18,  2.09s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 11/709 [00:23<24:22,  2.10s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 12/709 [00:25<23:52,  2.06s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 13/709 [00:27<24:09,  2.08s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 14/709 [00:29<24:05,  2.08s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 15/709 [00:31<23:06,  2.00s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 16/709 [00:33<22:42,  1.97s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   2%|▏         | 17/709 [00:35<21:50,  1.89s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 18/709 [00:37<21:30,  1.87s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 19/709 [00:39<21:10,  1.84s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 20/709 [00:40<20:31,  1.79s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 21/709 [00:42<19:35,  1.71s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 22/709 [00:43<19:03,  1.66s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 23/709 [00:45<18:51,  1.65s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   3%|▎         | 24/709 [00:46<18:09,  1.59s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▎         | 25/709 [00:48<18:18,  1.61s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▎         | 26/709 [00:50<18:12,  1.60s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▍         | 27/709 [00:51<18:44,  1.65s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▍         | 28/709 [00:53<18:59,  1.67s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▍         | 29/709 [00:56<21:55,  1.93s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▍         | 30/709 [00:58<23:26,  2.07s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   4%|▍         | 31/709 [01:01<25:22,  2.25s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▍         | 32/709 [01:03<26:21,  2.34s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▍         | 33/709 [01:06<26:57,  2.39s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▍         | 34/709 [01:08<26:22,  2.34s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▍         | 35/709 [01:10<26:45,  2.38s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▌         | 36/709 [01:13<26:40,  2.38s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▌         | 37/709 [01:15<26:41,  2.38s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   5%|▌         | 38/709 [01:17<25:50,  2.31s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▌         | 39/709 [01:20<26:06,  2.34s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▌         | 40/709 [01:22<25:20,  2.27s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▌         | 41/709 [01:24<26:20,  2.37s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▌         | 42/709 [01:27<26:31,  2.39s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▌         | 43/709 [01:32<34:46,  3.13s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▌         | 44/709 [01:37<40:23,  3.64s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▋         | 45/709 [01:42<45:41,  4.13s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   6%|▋         | 46/709 [01:47<48:11,  4.36s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 47/709 [01:52<50:35,  4.59s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 48/709 [01:57<51:16,  4.66s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 49/709 [02:02<52:56,  4.81s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 50/709 [02:07<52:48,  4.81s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 51/709 [02:11<52:44,  4.81s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 52/709 [02:16<51:01,  4.66s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   7%|▋         | 53/709 [02:21<51:55,  4.75s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 54/709 [02:25<51:16,  4.70s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 55/709 [02:30<51:53,  4.76s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 56/709 [02:35<51:35,  4.74s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 57/709 [02:38<47:44,  4.39s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 58/709 [02:42<44:44,  4.12s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 59/709 [02:45<42:42,  3.94s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   8%|▊         | 60/709 [02:49<41:34,  3.84s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▊         | 61/709 [02:53<41:11,  3.81s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▊         | 62/709 [02:56<39:25,  3.66s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▉         | 63/709 [03:00<38:26,  3.57s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▉         | 64/709 [03:03<38:01,  3.54s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▉         | 65/709 [03:06<36:42,  3.42s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▉         | 66/709 [03:09<35:32,  3.32s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#   9%|▉         | 67/709 [03:13<36:05,  3.37s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|▉         | 68/709 [03:16<35:31,  3.33s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|▉         | 69/709 [03:19<35:22,  3.32s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|▉         | 70/709 [03:23<35:32,  3.34s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|█         | 71/709 [03:26<34:24,  3.24s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|█         | 72/709 [03:29<33:22,  3.14s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|█         | 73/709 [03:31<32:25,  3.06s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  10%|█         | 74/709 [03:34<31:11,  2.95s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█         | 75/709 [03:37<31:23,  2.97s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█         | 76/709 [03:40<30:40,  2.91s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█         | 77/709 [03:43<30:17,  2.88s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█         | 78/709 [03:45<29:41,  2.82s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█         | 79/709 [03:48<29:34,  2.82s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█▏        | 80/709 [03:51<29:06,  2.78s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  11%|█▏        | 81/709 [03:54<29:34,  2.83s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 82/709 [03:56<28:09,  2.69s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 83/709 [03:59<29:11,  2.80s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 84/709 [04:02<29:11,  2.80s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 85/709 [04:04<25:39,  2.47s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 86/709 [04:06<23:56,  2.31s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 87/709 [04:07<22:30,  2.17s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  12%|█▏        | 88/709 [04:09<20:33,  1.99s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 89/709 [04:11<19:44,  1.91s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 90/709 [04:13<19:16,  1.87s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 91/709 [04:15<19:39,  1.91s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 92/709 [04:16<19:17,  1.88s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 93/709 [04:18<18:28,  1.80s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 94/709 [04:19<17:21,  1.69s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  13%|█▎        | 95/709 [04:21<17:44,  1.73s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▎        | 96/709 [04:23<17:26,  1.71s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▎        | 97/709 [04:25<17:23,  1.70s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▍        | 98/709 [04:26<17:10,  1.69s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▍        | 99/709 [04:30<22:01,  2.17s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▍        | 100/709 [04:32<24:12,  2.39s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▍        | 101/709 [04:36<27:01,  2.67s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  14%|█▍        | 102/709 [04:39<27:59,  2.77s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▍        | 103/709 [04:42<28:13,  2.79s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▍        | 104/709 [04:44<27:38,  2.74s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▍        | 105/709 [04:47<29:03,  2.89s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▍        | 106/709 [04:50<29:20,  2.92s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▌        | 107/709 [04:53<28:57,  2.89s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▌        | 108/709 [04:56<27:55,  2.79s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  15%|█▌        | 109/709 [04:59<29:05,  2.91s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▌        | 110/709 [05:02<29:17,  2.93s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▌        | 111/709 [05:05<28:46,  2.89s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▌        | 112/709 [05:08<29:03,  2.92s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▌        | 113/709 [05:12<33:28,  3.37s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▌        | 114/709 [05:16<35:45,  3.61s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▌        | 115/709 [05:20<37:08,  3.75s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  16%|█▋        | 116/709 [05:25<38:45,  3.92s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 117/709 [05:29<39:20,  3.99s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 118/709 [05:33<38:39,  3.92s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 119/709 [05:37<40:01,  4.07s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 120/709 [05:41<39:13,  4.00s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 121/709 [05:45<39:12,  4.00s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 122/709 [05:48<37:43,  3.86s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 123/709 [05:53<38:48,  3.97s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  17%|█▋        | 124/709 [05:56<37:12,  3.82s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  18%|█▊        | 125/709 [06:00<37:32,  3.86s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  18%|█▊        | 126/709 [06:04<36:54,  3.80s/it]c:\Users\fraxi\.conda\envs\DL\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
#  18%|█▊        | 127/709 [07:29<4:35:02, 28.36s/it]
